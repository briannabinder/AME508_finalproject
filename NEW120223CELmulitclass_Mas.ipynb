# %% [markdown]
# <a href="https://colab.research.google.com/github/briannabinder/AME508_finalproject/blob/main/NEW120223CELmulitclass_Mas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
import requests
import base64
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
import scipy
from torch.utils.data import Dataset, DataLoader
from torch.utils.data import DataLoader, TensorDataset
from scipy import signal
from scipy.io import wavfile
from torchsummary import summary
from skimage.transform import resize
from skimage import io, transform
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize

# %%
folder_path = 'G:\My Drive\Colab_Notebooks\Project_Datasets\Train_Datasets'
folder_path1 ='G:\My Drive\Colab_Notebooks\Project_Datasets\Test_Datasets'

# %% [markdown]
# Train datasets Label Reader Mulit Hot Incoder

# %%
# Get a list of all files in the folder
file_list = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

# Specify the labels to encode
labels_to_encode = ['Wheeze', 'Stridor', 'Rhonchi']

# List to store all multi-hot encoded matrices
all_multi_hot_matrices = []
all_filtered_name_1 =[]

# Iterate through each file
for file_name in file_list:
    if file_name.endswith('.txt'):  # Check if the file is a .txt file
        file_path = os.path.join(folder_path, file_name)

        # Read the content of the .txt file with different encodings
        for encoding in ['utf-8', 'latin-1', 'ISO-8859-1']:
            try:
                with open(file_path, 'r', encoding=encoding) as file:
                    label_lines = file.readlines()
                break  # Stop trying encodings if successful
            except UnicodeDecodeError:
                continue  # Try the next encoding if decoding fails

        # Parse labels and time intervals
        labels_and_intervals = []
        for line in label_lines:
            parts = line.strip().split()
            if parts and parts[0] != 'D':  # Check if the line is not empty and doesn't start with 'D'
                label = parts[0]
                labels_and_intervals.append(label)

        # Create a single-row multi-hot encoded matrix for the current file
        multi_hot_encoded_vector = []

        # Check if any of the specified labels are detected
        labels_detected = any(label_row in labels_and_intervals for label_row in labels_to_encode)

        for label_row in labels_to_encode:
            # Check if the label_row is in the labels_and_intervals
            if label_row in labels_and_intervals:
                multi_hot_vector = 1
            else:
                multi_hot_vector = 0

            multi_hot_encoded_vector.append(multi_hot_vector)

        # If none of the specified labels are detected, set 'Normal' to 1
        #if not labels_detected:
        #    multi_hot_encoded_vector[-1] = 1


        # Check if there are multiple occurrences of '1' in the multi-hot vector
        if multi_hot_encoded_vector.count(1) == 1:
            # Append the multi-hot encoded vector to the list
            all_multi_hot_matrices.append({
                'file_name': file_name,
                'vector': multi_hot_encoded_vector
            })

        else:
            print(f"Excluded file: {file_name}, multi-hot vector: {multi_hot_encoded_vector}")
            # Append the multi-hot encoded vector to the list
            all_filtered_name_1.append({
            'file_name': file_name,
            'vector': multi_hot_encoded_vector
            })

# Create a NumPy array to store all the vectors
multi_hot_matrices = np.array([item['vector'] for item in all_multi_hot_matrices])

# Print the total count of files
#print(all_multi_hot_matrices.shape)
# Out:
# Streaming output truncated to the last 5000 lines.
# Excluded file: steth_20190728_13_20_33_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190728_13_44_00_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190702_14_50_17_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190728_13_45_52_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190702_14_48_18_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190702_14_49_50_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190728_13_47_11_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190728_13_47_33_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190702_14_48_47_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190702_14_47_56_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190702_14_57_10_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190702_14_54_37_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190702_14_56_13_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190702_14_54_01_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190702_14_50_40_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190702_14_55_26_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190702_14_55_48_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190702_14_56_48_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190702_14_51_03_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190702_14_55_04_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190724_11_39_53_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190724_11_40_18_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190724
label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-37-49-L5_13_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-37-49-L5_7_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-37-49-L5_4_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L4_13_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-31-14-37-49-L5_5_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L2_1_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L4_4_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L4_2_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L2_0_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L2_3_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L2_2_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L2_4_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L4_1_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L1_4_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L1_0_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L1_2_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L1_5_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L1_3_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L1_1_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L8_1_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L8_4_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L8_0_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L8_3_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L8_2_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L1_7_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L6_2_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L6_3_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L6_0_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L6_4_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L6_1_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L5_3_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L5_0_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L4_10_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L4_0_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L5_2_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-14-59-53-L5_1_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L4_11_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L4_12_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L4_2_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L4_3_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L4_13_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L4_1_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L2_2_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L2_7_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L2_6_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L1_12_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L1_2_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L1_7_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L1_11_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L2_8_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L1_6_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L1_3_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L2_9_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L6_1_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L6_3_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L6_6_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L6_9_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L6_7_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L6_8_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L6_4_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L6_2_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L5_3_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L5_2_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-30-21-L4_14_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-08-03-L5_1_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-30-21-L1_14_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-30-21-L1_11_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-30-21-L2_14_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-30-21-L2_13_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-30-21-L1_12_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-30-21-L1_13_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-30-21-L2_12_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-30-21-L6_14_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-30-21-L8_14_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-30-21-L6_13_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-30-21-L8_13_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-38-07-L4_0_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-30-21-L5_14_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-30-21-L5_13_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-38-07-L2_0_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-38-07-L4_13_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-38-07-L6_13_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-38-07-L6_5_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-38-07-L6_7_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-38-07-L6_1_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-38-07-L6_4_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-31-15-38-07-L6_3_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L4_6_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L4_3_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L4_4_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L4_1_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L2_5_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L4_7_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L2_6_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L2_1_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L2_4_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L1_2_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L2_3_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L2_7_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L2_8_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L1_6_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L1_8_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L1_9_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L1_3_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L8_8_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L8_0_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L8_4_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L8_6_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L6_1_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L5_3_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L6_7_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L6_8_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L5_6_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L5_1_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L6_6_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L5_0_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L5_9_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L4_11_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L4_4_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-07-13-L5_8_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L4_2_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L4_12_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L4_6_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L2_14_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L2_11_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L4_5_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L2_10_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L4_9_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L4_7_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L1_0_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L2_7_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L1_6_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L1_3_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L1_5_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L1_2_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L1_4_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L1_14_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L1_12_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L1_11_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L8_14_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L8_0_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L1_8_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L8_13_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L6_7_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L6_5_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L6_9_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L5_11_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L6_2_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L6_11_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L6_1_label.txt, multi-hot vector: [1, 1, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L6_10_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L8_3_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: trunc_2019-05-28-14-44-45-L6_14_label.txt, multi-hot vector: [1, 1, 0]

# %%
# Display the first 20 examples and their labels matrix
print(multi_hot_matrices.shape)

for i in range(min(5, len(all_multi_hot_matrices))):
    example = all_multi_hot_matrices[i]
    file_name = example['file_name']
    vector = example['vector']

    print(f"Example {i + 1} - File: {file_name}")
    print(f"Labels Matrix: {vector}")
    print()


# Extract base filenames by removing '_label.txt' from 'file_name'
base_filenames_1 = [os.path.splitext(item['file_name'])[0].replace('_label', '') for item in all_filtered_name_1]

# Create a new list with modified 'file_name' values
all_filtered_name_1_modified = [{'file_name': base_filename + '.wav', 'vector': item['vector']} for base_filename, item in zip(base_filenames_1, all_filtered_name_1)]

print(all_filtered_name_1_modified)
# Out:
# (2630, 3)
# Example 1 - File: steth_20190729_13_41_48_label.txt
# Labels Matrix: [1, 0, 0]
#
# Example 2 - File: steth_20190729_13_43_50_label.txt
# Labels Matrix: [1, 0, 0]
#
# Example 3 - File: steth_20190729_13_44_54_label.txt
# Labels Matrix: [1, 0, 0]
#
# Example 4 - File: steth_20190729_13_42_37_label.txt
# Labels Matrix: [1, 0, 0]
#
# Example 5 - File: steth_20190729_13_44_27_label.txt
# Labels Matrix: [1, 0, 0]
#
# [{'file_name': 'steth_20190717_11_41_15.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190717_11_41_36.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190717_11_42_23.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190717_11_41_59.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190717_12_04_42.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190717_12_07_46.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190717_12_03_45.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190717_12_06_02.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190717_11_42_49.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190717_12_05_14.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190717_12_04_10.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190717_12_07_03.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190717_12_06_37.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190717_12_08_07.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190717_12_05_33.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190717_12_07_24.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_14_17_38.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_14_18_12.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_14_16_49.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190717_12_08_53.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_13_43_00.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190717_12_08_27.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_14_17_15.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_13_43_24.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_14_19_28.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_14_28_21.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_14_20_02.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_14_29_20.wav', 'vector': [1, 0, 1]}, {'file_name': 'steth_20190729_14_19_01.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_14_30_28.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_14_18_35.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_14_31_14.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_14_31_44.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_14_30_53.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_14_43_31.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_14_42_48.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_14_41_47.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_14_45_35.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190730_10_11_17.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190730_10_11_47.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_14_32_06.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190730_10_09_12.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_14_44_05.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_14_42_19.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190730_10_10_51.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190730_10_09_46.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190730_10_10_25.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190729_14_45_04.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190730_12_05_25.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190730_10_12_42.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190730_12_06_43.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190730_10_12_16.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190730_12_04_59.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190730_12_07_16.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190730_12_04_12.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190730_12_07_40.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190701_10_05_56.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190701_10_04_40.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190701_10_01_38.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190701_10_02_24.wav', ' ...

# %% [markdown]
# Train dataset image

# %%
# Get a list of all files in the folder
file_list = [f for f in os.listdir(folder_path) if f.endswith('.wav')]


all_spectrograms_1 = []

steth_sample_rate = 4000
duration = 15
total_samples = steth_sample_rate * duration
num_freq_bins = 224
num_time_steps = 224

nperseg = 2 * num_freq_bins - 1  # (Nyquist limit)

  # num_time_steps = (total samples - noverlap) / (nperseg - noverlap)
  # t = s - o / p - o
  # tp - to = s - o
  # o = (tp - s) / (t - 1)

noverlap =  round((num_time_steps * nperseg - total_samples) / (num_time_steps - 1))
print("nperseg:", nperseg, "noverlap:", noverlap)

# Iterate through each .wav file in the folder
for wav_file in file_list:
    # Construct the full path to the .wav file
    wav_file_path = os.path.join(folder_path, wav_file)

    # Check if the modified .wav file name is NOT in all_filtered_name_1_modified
    modified_wav_file_name1 = os.path.splitext(wav_file.replace('_label', ''))[0] + '.wav'
    # Check if the modified .wav file name is NOT in all_filtered_name_2_modified
    if not any(item['file_name'] == modified_wav_file_name1 for item in all_filtered_name_1_modified):
      # Read the WAV file
      sample_rate, samples = wavfile.read(wav_file_path)

      # Compute the spectrogram
      frequencies, times, spectrogram = scipy.signal.spectrogram(samples, fs=sample_rate, nperseg=nperseg, noverlap=noverlap)

      # Apply logarithmic transformation
      log_spectrogram = 10 * np.log10(spectrogram)


      # Trim the spectrogram to have a shape of (224, 224)
      # log_spectrogram = log_spectrogram[:224, :224]


      # Store the log_spectrogram in the list
      all_spectrograms_1.append(log_spectrogram)


# Print the shape of the first spectrogram
print(f"File: {file_list[0]}, Spectrogram shape: {all_spectrograms_1[0].shape}")



# Plot the first spectrogram
plt.pcolormesh(times, frequencies, all_spectrograms_1[0], shading='auto')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.title(f'Spectrogram - {file_list[0]}')
plt.colorbar(label='Intensity [dB]')
plt.show()
all_spectrograms_1 = np.reshape(np.array(all_spectrograms_1), newshape=(2630,1,224,224))
# Out:
# nperseg: 447 noverlap: 180
# File: steth_20190622_15_04_06.wav, Spectrogram shape: (224, 224)

# %% [markdown]
# Test_datasets Label Reader Mulit Hot Incoder

# %%
# Get a list of all files in the folder
file_list2 = [f for f in os.listdir(folder_path1) if os.path.isfile(os.path.join(folder_path1, f))]

# Specify the labels to encode
labels_to_encode = ['Wheeze', 'Stridor', 'Rhonchi']

# List to store all multi-hot encoded matrices
all_multi_hot_matrices_2 = []
all_filtered_name_2 =[]

# Iterate through each file
for file_name in file_list2:
    if file_name.endswith('.txt'):  # Check if the file is a .txt file
        file_path = os.path.join(folder_path1, file_name)

        # Read the content of the .txt file with different encodings
        for encoding in ['utf-8', 'latin-1', 'ISO-8859-1']:
            try:
                with open(file_path, 'r', encoding=encoding) as file:
                    label_lines = file.readlines()
                break  # Stop trying encodings if successful
            except UnicodeDecodeError:
                continue  # Try the next encoding if decoding fails

        # Parse labels and time intervals
        labels_and_intervals = []
        for line in label_lines:
            parts = line.strip().split()
            if parts and parts[0] != 'D':  # Check if the line is not empty and doesn't start with 'D'
                label = parts[0]
                labels_and_intervals.append(label)

        # Create a single-row multi-hot encoded matrix for the current file
        multi_hot_encoded_vector1 = []

        # Check if any of the specified labels are detected
        labels_detected = any(label_row in labels_and_intervals for label_row in labels_to_encode)


        for label_row in labels_to_encode:
            # Check if the label_row is in the labels_and_intervals
            if label_row in labels_and_intervals:
                multi_hot_vector = 1
            else:
                multi_hot_vector = 0

            multi_hot_encoded_vector1.append(multi_hot_vector)

        # If none of the specified labels are detected, set 'Normal' to 1
        #if not labels_detected:
        #    multi_hot_encoded_vector1[-1] = 1


        # Append the multi-hot encoded vector to the list
        # Check if there are multiple occurrences of '1' in the multi-hot vector
        if multi_hot_encoded_vector1.count(1) == 1:
            # Append the multi-hot encoded vector to the list
             all_multi_hot_matrices_2.append({
                'file_name': file_name,
                'vector': multi_hot_encoded_vector1
            })
        else:
            print(f"Excluded file: {file_name}, multi-hot vector: {multi_hot_encoded_vector1}")
            all_filtered_name_2.append({
            'file_name': file_name,
            'vector': multi_hot_encoded_vector1
            })


# Create a NumPy array to store all the vectors
multi_hot_matrices_2 = np.array([item['vector'] for item in all_multi_hot_matrices_2])
#all_filtered_name_2 =  np.array([item['file_name'] for item in all_filtered_name_2])
#multi_hot_matrices_2 = multi_hot_matrices_2.reshape(-1.1)
print(multi_hot_matrices_2.shape)
# Out:
# Excluded file: steth_20190821_08_51_02_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190824_21_47_03_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190824_21_49_08_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190816_22_13_09_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190821_08_46_54_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190821_08_46_00_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190816_22_15_21_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190824_21_52_59_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190822_14_54_41_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190816_22_15_48_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190824_21_50_21_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190816_22_12_31_label.txt, multi-hot vector: [0, 0, 0]
# Excluded file: steth_20190824
wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190816_22_13_09.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_08_46_54.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_08_46_00.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190816_22_15_21.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190824_21_52_59.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190822_14_54_41.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190816_22_15_48.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190824_21_50_21.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190816_22_12_31.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190824_21_47_32.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_12_16.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_05_58.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_11_47.wav', 'vector': [1, 0, 1]}, {'file_name': 'steth_20190821_10_04_23.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_04_50.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_07_28.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_03_58.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_31_30.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_30_17.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_30_48.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_14_10.wav', 'vector': [1, 0, 1]}, {'file_name': 'steth_20190821_10_29_26.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_31_21.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_30_54.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_29_50.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_37_50.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_37_24.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_33_02.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_31_50.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_32_54.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_32_36.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_32_22.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_39_27.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_32_11.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_10_31_55.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_11_03_37.wav', 'vector': [1, 0, 1]}, {'file_name': 'steth_20190821_11_02_45.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_11_02_05.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_11_04_22.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_11_03_51.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_11_02_27.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_11_35_43.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_11_35_03.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_11_33_44.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_11_04_42.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_11_36_55.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_11_34_06.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_11_33_01.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_11_36_38.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_11_36_29.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_11_36_07.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_11_35_18.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_11_36_15.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_12_00_25.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_12_03_02.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_12_01_47.wav', 'vector': [0, 0, 0]}, {'file_name': 'steth_20190821_12_23_53.wav', ' ...

# %% [markdown]
# Test datasets .wav

# %%
# Get a list of all files in the folder
file_list1 = [f for f in os.listdir(folder_path1) if f.endswith('.wav')]

all_spectrograms_2 = []

steth_sample_rate = 4000
duration = 15
total_samples = steth_sample_rate * duration
num_freq_bins = 224
num_time_steps = 224

nperseg = 2 * num_freq_bins - 1  # (Nyquist limit)

  # num_time_steps = (total samples - noverlap) / (nperseg - noverlap)
  # t = s - o / p - o
  # tp - to = s - o
  # o = (tp - s) / (t - 1)

noverlap =  round((num_time_steps * nperseg - total_samples) / (num_time_steps - 1))
print("nperseg:", nperseg, "noverlap:", noverlap)

# Iterate through each .wav file in the folder
for wav_file in file_list1:
    # Construct the full path to the .wav file
    wav_file_path = os.path.join(folder_path1, wav_file)

    modified_wav_file_name = os.path.splitext(wav_file.replace('_label', ''))[0] + '.wav'
    # Check if the modified .wav file name is NOT in all_filtered_name_2_modified
    if not any(item['file_name'] == modified_wav_file_name for item in all_filtered_name_2_modified):

        # Read the WAV file
        sample_rate, samples = wavfile.read(wav_file_path)

        # Compute the spectrogram
        frequencies, times, spectrogram = scipy.signal.spectrogram(samples, fs=sample_rate, nperseg=nperseg, noverlap=noverlap)

        # Apply logarithmic transformation
        log_spectrogram = 10 * np.log10(spectrogram)


        # Trim the spectrogram to have a shape of (224, 224)
        # log_spectrogram = log_spectrogram[:224, :224]


        # Store the log_spectrogram in the list
        all_spectrograms_2.append(log_spectrogram)


# Print the shape of the first spectrogram
print(f"File: {file_list1[0]}, Spectrogram shape: {all_spectrograms_2[0].shape}")



# Plot the first spectrogram
plt.pcolormesh(times, frequencies, all_spectrograms_2[0], shading='auto')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.title(f'Spectrogram - {file_list1[0]}')
plt.colorbar(label='Intensity [dB]')
plt.show()

all_spectrograms_2 = np.reshape(np.array(all_spectrograms_2), newshape=(609,1,224,224))
# Out:
# nperseg: 447 noverlap: 180
# File: steth_20190808_10_49_19.wav, Spectrogram shape: (224, 224)

# %%
print(all_spectrograms_2.shape)
# Out:
# (609, 1, 224, 224)

# %% [markdown]
# Train datasets Label Reader Mulit Hot Incoder

# %% [markdown]
# CustomDataset

# %%
class CustomDataset(Dataset):
    def __init__(self, samples, labels):
        """
        Initialize the CustomDataset with paired samples.

        Args:
            samples (list of tuples): A list of (x, y) pairs representing the dataset samples.
        """
        self.samples = torch.Tensor(samples).to(torch.float32)
        self.labels = torch.Tensor(labels).to(torch.float32)

    def __len__(self):
        """
        Returns the length of the dataset, i.e., the number of samples.
        """
        return len(self.samples)

    def __getitem__(self, idx):
        """
        Returns the sample pairs corresponding to the given list of indices.

        Args:
            indices (list): A list of indices to retrieve samples for.

        Returns:
            list: A list of (x, y) pairs corresponding to the specified indices.
        """
        selected_sample = self.samples[idx]
        selected_label = self.labels[idx]
        return selected_sample , selected_label

# %%
batch_size = 32

train_dataset = CustomDataset(all_spectrograms_1,multi_hot_matrices)

test_dataset = CustomDataset(all_spectrograms_2,multi_hot_matrices_2)

trainloader = torch.utils.data.DataLoader(train_dataset,batch_size=batch_size , shuffle=True)

testloader = torch.utils.data.DataLoader(test_dataset, shuffle=True, batch_size=batch_size)

# %% [markdown]
#  VGG16 CNN as feature extractors

# %%
class VGG16(nn.Module):
    def __init__(self, verbose=False):
        super(VGG16, self).__init__()
        self.conv1_1 = nn.Conv2d(1, 64, kernel_size=3, padding=1)
        self.conv1_2 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.conv2_1 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv2_2 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.conv3_1 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv3_2 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.conv3_3 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.conv4_1 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.conv4_2 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv4_3 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.conv5_1 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv5_2 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv5_3 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.pool5 = nn.MaxPool2d(kernel_size=2, stride=2)

        self.fc1 = nn.Linear(25088, 4096)
        self.dropout = nn.Dropout(0.5)  # Add dropout with a probability of 0.5
        self.fc2 = nn.Linear(4096, 4096)
        self.dropout = nn.Dropout(0.5)  # Add dropout with a probability of 0.5
        self.fc3 = nn.Linear(4096, 3)

        self.verbose = verbose

    def forward(self, x):
        if self.verbose:
            print(f"Input shape: {x.size()}")

        x = F.relu(self.conv1_1(x))
        x = F.relu(self.conv1_2(x))
        x = self.pool1(x)
        if self.verbose:
            print(f"After Layer 1: {x.size()}")

        x = F.relu(self.conv2_1(x))
        x = F.relu(self.conv2_2(x))
        x = self.pool2(x)
        if self.verbose:
            print(f"After Layer 2: {x.size()}")

        x = F.relu(self.conv3_1(x))
        x = F.relu(self.conv3_2(x))
        x = F.relu(self.conv3_3(x))
        x = self.pool3(x)
        if self.verbose:
            print(f"After Layer 3: {x.size()}")

        x = F.relu(self.conv4_1(x))
        x = F.relu(self.conv4_2(x))
        x = F.relu(self.conv4_3(x))
        x = self.pool4(x)
        if self.verbose:
            print(f"After Layer 4: {x.size()}")

        x = F.relu(self.conv5_1(x))
        x = F.relu(self.conv5_2(x))
        x = F.relu(self.conv5_3(x))
        x = self.pool5(x)
        if self.verbose:
            print(f"After Layer 5 {x.size()}")

        x = torch.flatten(x,1)
        #x = torch.unsqueeze(1,x)
        if self.verbose:
            print(f"Flattened: {x.size()}")

        x = F.relu(self.fc1(x))
        if self.verbose:
            print(f"After first Fully connected layer: {x.size()}")

        x = self.dropout(x)  # Apply dropout
        if self.verbose:
            print(f"After dropout: {x.size()}")

        x = F.relu(self.fc2(x))
        if self.verbose:
            print(f"After Secound Fully connected layer: {x.size()}")

        x = self.dropout(x)  # Apply dropout
        if self.verbose:
            print(f"After dropout: {x.size()}")

        x = self.fc3(x)

        # Apply softmax activation to the last layer
        #x = F.softmax(x,1)
        #x = torch.softmax(x,1)
        x = torch.sigmoid(x)
        if self.verbose:
            print(f"Output shape: {x.size()}")

        return x

# %% [markdown]
# Check for GPU

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# Assuming that we are on a CUDA machine, this should print a CUDA device:
print(device)
# Out:
# cuda:0

# %% [markdown]
# Testing VGG16 CNN shape size

# %%
print("Intermediate shapes for VGG16")
model = VGG16(verbose=True)
output = model(torch.ones(size=(1,1,224,224)))
# More infor on VGG16 (https://builtin.com/machine-learning/vgg16)
# Out:
# Intermediate shapes for VGG16
# Input shape: torch.Size([1, 1, 224, 224])
# After Layer 1: torch.Size([1, 64, 112, 112])
# After Layer 2: torch.Size([1, 128, 56, 56])
# After Layer 3: torch.Size([1, 256, 28, 28])
# After Layer 4: torch.Size([1, 512, 14, 14])
# After Layer 5 torch.Size([1, 512, 7, 7])
# Flattened: torch.Size([1, 25088])
# After first Fully connected layer: torch.Size([1, 4096])
# After dropout: torch.Size([1, 4096])
# After Secound Fully connected layer: torch.Size([1, 4096])
# After dropout: torch.Size([1, 4096])
# Output shape: torch.Size([1, 3])

# %%
torch.cuda.empty_cache()

torch.cuda.memory_summary(device=None, abbreviated=False)
# Out:
# '|===========================================================================|\n|                  PyTorch CUDA memory summary, device ID 0                 |\n|---------------------------------------------------------------------------|\n|            CUDA OOMs: 0            |        cudaMalloc retries: 0         |\n|===========================================================================|\n|        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |\n|---------------------------------------------------------------------------|\n| Allocated memory      |   2069 MiB |   5661 MiB |  22344 GiB |  22342 GiB |\n|       from large pool |   2064 MiB |   5656 MiB |  22329 GiB |  22327 GiB |\n|       from small pool |      4 MiB |      6 MiB |     15 GiB |     15 GiB |\n|---------------------------------------------------------------------------|\n| Active memory         |   2069 MiB |   5661 MiB |  22344 GiB |  22342 GiB |\n|       from large pool |   2064 MiB |   5656 MiB |  22329 GiB |  22327 GiB |\n|       from small pool |      4 MiB |      6 MiB |     15 GiB |     15 GiB |\n|---------------------------------------------------------------------------|\n| Requested memory      |   2065 MiB |   5657 MiB |  22336 GiB |  22334 GiB |\n|       from large pool |   2060 MiB |   5652 MiB |  22321 GiB |  22319 GiB |\n|       from small pool |      4 MiB |      6 MiB |     15 GiB |     15 GiB |\n|---------------------------------------------------------------------------|\n| GPU reserved memory   |   4276 MiB |   5966 MiB |   5966 MiB |   1690 MiB |\n|       from large pool |   4268 MiB |   5958 MiB |   5958 MiB |   1690 MiB |\n|       from small pool |      8 MiB |      8 MiB |      8 MiB |      0 MiB |\n|---------------------------------------------------------------------------|\n| Non-releasable memory |   2206 MiB |   2712 MiB |  16638 GiB |  16636 GiB |\n|       from large pool |   2203 MiB |   2710 MiB |  16622 GiB |  16620 GiB |\n|       from small pool |      3 MiB |      6 MiB |     15 GiB |     15 GiB |\n|---------------------------------------------------------------------------|\n| Allocations           |     134    |     166    |  295948    |  295814    |\n|       from large pool |      46    |      72    |  167091    |  167045    |\n|       from small pool |      88    |     109    |  128857    |  128769    |\n|---------------------------------------------------------------------------|\n| Active allocs         |     134    |     166    |  295948    |  295814    |\n|       from large pool |      46    |      72    |  167091    |  167045    |\n|       from small pool |      88    |     109    |  128857    |  128769    |\n|---------------------------------------------------------------------------|\n| GPU reserved segments |      18    |      23    |      23    |       5    |\n|       from large pool |      14    |      19    |      19    |       5    |\n|       from small pool |       4    |       4    |       4    |       0    |\n|---------------------------------------------------------------------------|\n| Non-releasable allocs |      24    |      38    |   88272    |   88248    |\n|       from large pool |      15    |      22    |   54801    |   54786    |\n|       from small pool |       9    |      17    |   33471    |   33462    |\n|---------------------------------------------------------------------------|\n| Oversize allocations  |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Oversize GPU segments |       0    |       0    |       0    |       0    |\n|===========================================================================|\n'

# %% [markdown]
# Training VGG16 CNN

# %%
from torch.nn.utils import clip_grad_norm_

max_grad_norm = 1.0  # Set your desired maximum gradient norm
model = VGG16().to(device)
criterion = nn.CrossEntropyLoss()
#criterion = nn.BCELoss()
learning_rate = 1e-4
optimizer = optim.Adam(model.parameters(),weight_decay=1e-8,lr = learning_rate)
n_epoch   = 1
n_batches = len(trainloader)
print_every = 10

loss_hist = np.zeros(n_epoch*n_batches)
acc_hist  = np.zeros(n_epoch*n_batches)

all_labels =[]
all_predictions =[]

it = 0
for epoch in range(n_epoch):  # loop over the dataset multiple times

    #loss = 0.0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        inputs = inputs/ 255

        # Print inputs and labels
        #print('Inputs:', inputs)
        #print('Labels:', labels)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = model(inputs.to(device))
        # Print raw outputs from the model
        #print("Raw Outputs:", outputs)
        loss = criterion(outputs, labels.to(device))
        loss.backward()

        # Clip gradients to prevent exploding gradients
        clip_grad_norm_(model.parameters(), max_norm=max_grad_norm)

        optimizer.step()

        # save loss
        loss_hist[it] = loss.item()
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        acc_hist[it] = 100.0*np.sum(predicted.cpu().numpy() == np.argmax(labels.numpy(), axis=1))/labels.size(0)

        #all_labels.extend(predicted.cpu().numpy())
        #all_predictions.extend(predicted.cpu().detach())
        # Append true labels and predicted labels
        # Assuming labels is one-hot encoded, convert it to class indices
        all_labels.extend(np.argmax(labels.cpu().numpy(), axis=1))
        all_predictions.extend(predicted.cpu().numpy())

        if (i+1) % print_every == 0:    # print every 50 mini-batches
            #vacc_hist[iter//print_every] = find_vacc(net,testloader)
            print('epoch = {}/{}, minibatch = {}/{}, loss = {}, accuracy = {}'.format(epoch+1, n_epoch, i+1, n_batches, loss.item(), acc_hist[it]))

        it+=1

print('Finished Training')
# Out:
# epoch = 1/1, minibatch = 10/83, loss = 0.926665186882019, accuracy = 62.5
# epoch = 1/1, minibatch = 20/83, loss = 0.7701947689056396, accuracy = 78.125
# epoch = 1/1, minibatch = 30/83, loss = 0.8014447689056396, accuracy = 75.0
# epoch = 1/1, minibatch = 40/83, loss = 0.8639447689056396, accuracy = 68.75
# epoch = 1/1, minibatch = 50/83, loss = 0.9576947689056396, accuracy = 59.375
# epoch = 1/1, minibatch = 60/83, loss = 0.8639447689056396, accuracy = 68.75
# epoch = 1/1, minibatch = 70/83, loss = 0.7701947689056396, accuracy = 78.125
# epoch = 1/1, minibatch = 80/83, loss = 0.8326947689056396, accuracy = 71.875
# Finished Training

# %% [markdown]
# Plotting training losses

# %%
fig, axs = plt.subplots(2, 1, figsize=(15, 10))
axs[0].plot(loss_hist, label = "TrainDatasets")
axs[0].set_yscale('log')
axs[0].set_ylabel('Training Loss')
axs[0].legend()


axs[1].plot(acc_hist, label = "TrainDatasets")
axs[1].set_ylabel('Accuracy [%]')
axs[1].set_xlabel('Iterations')
axs[1].legend()

# %% [markdown]
# Testing

# %%
torch.cuda.empty_cache()

torch.cuda.memory_summary(device=None, abbreviated=False)
# Out:
# '|===========================================================================|\n|                  PyTorch CUDA memory summary, device ID 0                 |\n|---------------------------------------------------------------------------|\n|            CUDA OOMs: 0            |        cudaMalloc retries: 0         |\n|===========================================================================|\n|        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |\n|---------------------------------------------------------------------------|\n| Allocated memory      |   3095 MiB |   5661 MiB |  37512 GiB |  37509 GiB |\n|       from large pool |   3088 MiB |   5656 MiB |  37487 GiB |  37484 GiB |\n|       from small pool |      6 MiB |      8 MiB |     25 GiB |     25 GiB |\n|---------------------------------------------------------------------------|\n| Active memory         |   3095 MiB |   5661 MiB |  37512 GiB |  37509 GiB |\n|       from large pool |   3088 MiB |   5656 MiB |  37487 GiB |  37484 GiB |\n|       from small pool |      6 MiB |      8 MiB |     25 GiB |     25 GiB |\n|---------------------------------------------------------------------------|\n| Requested memory      |   3089 MiB |   5657 MiB |  37501 GiB |  37497 GiB |\n|       from large pool |   3083 MiB |   5652 MiB |  37475 GiB |  37472 GiB |\n|       from small pool |      6 MiB |      8 MiB |     25 GiB |     25 GiB |\n|---------------------------------------------------------------------------|\n| GPU reserved memory   |   4174 MiB |   7240 MiB |  11152 MiB |   6978 MiB |\n|       from large pool |   4166 MiB |   7230 MiB |  11142 MiB |   6976 MiB |\n|       from small pool |      8 MiB |     10 MiB |     10 MiB |      2 MiB |\n|---------------------------------------------------------------------------|\n| Non-releasable memory |   1078 MiB |   2712 MiB |  31182 GiB |  31181 GiB |\n|       from large pool |   1077 MiB |   2710 MiB |  31156 GiB |  31154 GiB |\n|       from small pool |      1 MiB |      6 MiB |     26 GiB |     26 GiB |\n|---------------------------------------------------------------------------|\n| Allocations           |     204    |     236    |  506459    |  506255    |\n|       from large pool |      68    |      84    |  281676    |  281608    |\n|       from small pool |     136    |     157    |  224783    |  224647    |\n|---------------------------------------------------------------------------|\n| Active allocs         |     204    |     236    |  506459    |  506255    |\n|       from large pool |      68    |      84    |  281676    |  281608    |\n|       from small pool |     136    |     157    |  224783    |  224647    |\n|---------------------------------------------------------------------------|\n| GPU reserved segments |      19    |      25    |      33    |      14    |\n|       from large pool |      15    |      20    |      28    |      13    |\n|       from small pool |       4    |       5    |       5    |       1    |\n|---------------------------------------------------------------------------|\n| Non-releasable allocs |      17    |      39    |  166083    |  166066    |\n|       from large pool |      13    |      22    |  102363    |  102350    |\n|       from small pool |       4    |      19    |   63720    |   63716    |\n|---------------------------------------------------------------------------|\n| Oversize allocations  |       0    |       0    |       0    |       0    |\n|---------------------------------------------------------------------------|\n| Oversize GPU segments |       0    |       0    |       0    |       0    |\n|===========================================================================|\n'

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
import seaborn as sns
# Find accuracy over testing set
test_labels = []
test_predictions = []
y_pred = []
y_true =[]
classes = ['Wheeze', 'Stridor', 'Rhonchi']
nb_classes = 3
# Initialize the prediction and label lists(tensors)

confusion_matrix = torch.zeros(nb_classes, nb_classes)
def find_vacc(net,loader):
    predlist=torch.zeros(0,dtype=torch.long, device='cpu')
    lbllist=torch.zeros(0,dtype=torch.long, device='cpu')

    correct = 0
    total = 0
    model.eval()  # Set the model to evaluation mode
    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for data in loader:
            images, labels = data
            # calculate outputs by running images through the network
            outputs = net(images.to(device))
            # the class with the highest energy is what we choose as prediction
            _, predicted = torch.max(outputs.data, 1)

            total += labels.size(0)
            correct += np.sum(predicted.cpu().numpy() == np.argmax(labels.numpy(), axis=1))
            #print(total)
            #print(correct)
            # Save true and predicted labels for further analysis
            y_true.extend(labels.numpy())
            y_pred.extend(predicted.cpu().detach().numpy())


    vacc = 100.0 * correct / total
    return vacc

test_acc = find_vacc(model, testloader)
print(f'Accuracy of the network trained on the test images: {test_acc} %')
# Out:
# Accuracy of the network trained on the test images: 58.29228243021346 %

# %% [markdown]
# Confusion matrix

# %%
import pandas as pd
# Convert lists to numpy arrays
#test_labels = np.argmax(test_labels, axis=1)
print(test_predictions)

#print(test_labels)
#test_predictions = np.argmax(test_predictions, axis=1)
classes = ['Wheeze', 'Stridor', 'Rhonchi']
conf_matrix_test = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(len(class_names), len(class_names)))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# []
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[250], line 9
#       6 #print(test_labels)
#       7 #test_predictions = np.argmax(test_predictions, axis=1)
#       8 classes = ['Wheeze', 'Stridor', 'Rhonchi']
# ----> 9 conf_matrix_test = confusion_matrix(y_true, y_pred)
#      11 plt.figure(figsize=(len(class_names), len(class_names)))
#      12 sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
#
# TypeError: 'Tensor' object is not callable
